# %%
#Importando matplot
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot([1,2,3], [4,5,6])
plt.show()

# %%
x = [1 , 4, 5]

# %%
y = [3, 7, 2]

# %%
#Criando plot com os valores das variaveis em parametro
#Definindo os nomes dos eixos x e y
#Inserindo titulo do plot
plt.plot(x,y)
plt.xlabel("Variavel 1")
plt.ylabel("Variavel 2")
plt.title('Teste')
# Out:
# Text(0.5, 1.0, 'Teste')

# %% [markdown]
# <h2> Gráfico de barras

# %%
x = [1,2,3,4,5,]
y = [7,8,9,10,11]

# %%
plt.bar(x,y,  label = "Barras", color="b")
plt.legend()
